# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshk312/Cat-Dog-Classifier/blob/master/flipkart_product_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib
import re
import subprocess
import requests
import sys
import time
from selenium import webdriver

# %%
flipkart_url = 'https://www.flipkart.com/realme-c2-diamond-black-32-gb/p/itmfgwba8kmejqpe?pid=MOBFHBZ4MDMCNHNK&lid=LSTMOBFHBZ4MDMCNHNKVPEYUE&marketplace=FLIPKART&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=organic&iid=58d6f9bd-b936-4576-b8fa-b8cb85236ea7.MOBFHBZ4MDMCNHNK.SEARCH&ssid=rw9w36yf280000001601635287235&qH=9ab62b5ef34a9854'
url2='https://www.flipkart.com/realme-c2-diamond-blue-32-gb/p/itmfgwba8kmejqpe?pid=MOBFHBZ4ZQB3CTZW&lid=LSTMOBFHBZ4ZQB3CTZWY5COWP&marketplace=FLIPKART&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=organic&iid=58d6f9bd-b936-4576-b8fa-b8cb85236ea7.MOBFHBZ4ZQB3CTZW.SEARCH&ssid=rw9w36yf280000001601635287235&qH=9ab62b5ef34a9854'

# %%
def send_text(msg):
	print("sending text")
	url = "https://www.fast2sms.com/dev/bulk"
	payload = "sender_id=FSTSMS&message="+ msg +"&language=english&route=p&numbers=9937021280"
	headers = {'authorization': "FwyRP3JnWuoi2ppU0L9b4cz2OrhnDUfRdHg6g8lVhawwH5cpF4XaFi2LhfoQ",'Content-Type': "application/x-www-form-urlencoded",'Cache-Control': "no-cache"}
	response = requests.request("POST", url, data=payload, headers=headers)
	print(response.text)

# %%
def track(flipkart_url):
    try:
        print("connecting")
        flipkart_fetch = requests.get(flipkart_url).text
        
        print("connected")
        product = re.findall('This item is currently out of stock', flipkart_fetch);
        if len(product) == 0: 
            message = "c2 2-32 black is back in stock at Flipkart "
            print(message)
            send_text(message)
            win32api.MessageBeep(0x00000010)
            win32api.MessageBox(0,message,"available")
        else:
            message = "Product is not available yet"
            print(message)
            #send_text(message)
            
    except:
        print("unable to connect wait for 60s")
        time.sleep(60)

# %%
def track2(flipkart_url):
    try:
        print("connecting")
        flipkart_fetch = requests.get(flipkart_url).text
        
        print("connected")
        product = re.findall('This item is currently out of stock', flipkart_fetch);
        if len(product) == 0: 
            message = "c2 2 32 blue is back in stock at Flipkart"
            print(message)
            send_text(message)
            win32api.MessageBeep(0x00000010)
            win32api.MessageBox(0,message,"available")
        else:
            message = "Product is not available yet"
            print(message)
    except:
        print("unable to connect wait for 60s")
        time.sleep(60)

# %%
def main():
        while(1):
            track(flipkart_url)
            track2(url2)
            time.sleep(2)
main()
# Out:
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# Product is not available yet
# connecting
# connected
# ...

# %%
send_text("from colab")
# Out:
# {"return":true,"request_id":"poz96vyj5hdtkg7","message":["Message sent successfully to NonDND numbers"]}
